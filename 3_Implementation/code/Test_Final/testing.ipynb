# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install -Uqq fastbook
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-git 0.11.0 requires nbdime<2.0.0,>=1.1.0, but you have nbdime 3.1.0 which is incompatible.

# %%
from fastai.vision import *
from fastai.vision.all import *

# %%
import fastbook
fastbook.setup_book()
from fastbook import *
from fastai.vision.widgets import *

# %%
import os
from fastai import *
from fastai.vision import *

# %%
me=load_learner('../input/saved-model/final.pkl','final.pkl')

# %%
rg=load_learner('../input/saved-model/RG (1).pkl')

# %%
test_path='../input/dataset/IDRid/Testing Set'

# %%
import pandas as pd
from PIL import *
import cv2

# %%
tst = pd.read_csv('../input/dataset/IDRid/Groundtruths/b. IDRiD_Disease Grading_Testing Labels.csv')
tst.tail()
# Out:
#     Image name  Retinopathy grade  Risk of macular edema
# 98   IDRiD_099                  0                       0
# 99   IDRiD_100                  2                       1
# 100  IDRiD_101                  1                       0
# 101  IDRiD_102                  2                       2
# 102  IDRiD_103                  0                       0

# %%
listdata=tst.values.tolist()

# %%
from fastai.vision import *

# %%
cnt=0
for i in os.listdir(test_path):
    name = i.split('.')[0]
    
    for j in listdata:
        if name == j[0]:
            label , y ,probability = me.predict(test_path+'/'+i)
            label1 , y1 ,probability = rg.predict(test_path+'/'+i)
            if int(label) == j[2] or int(label1)== j[1]:
                cnt=cnt+1

# %%
acc_both_true = cnt/103 * 100
print(acc_both_true)
# Out:
# 68.93203883495146

# %%
acc_any_true = cnt/103 * 100
print(acc_any_true)
# Out:
# 98.05825242718447
